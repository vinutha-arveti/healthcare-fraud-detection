# %% [markdown]
# # Healthcare Fraud Detection
#
# This notebook demonstrates the workflow used to detect fraudulent healthcare claims using machine learning.
#
# Steps included:
# - Data preprocessing
# - Exploratory Data Analysis (EDA)
# - Feature engineering
# - Model training and evaluation
